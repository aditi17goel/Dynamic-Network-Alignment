# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi17goel/Dynamic-Graph-Alignment/blob/main/KL_Divergence_Symmetric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import pandas as pd
import csv
import glob

# %%
path = '/content/drive/MyDrive/coauthor' 
all_files = glob.glob(path + "/*.txt")

df = []

for filename in all_files:
    temp = pd.read_csv(filename, delimiter="\t", header = None, on_bad_lines='skip')
    df.append(temp)

# %%
df[0].head()
# Out:
#          0       1
# 0   786433  723764
# 1  1310724   73633
# 2  1441797  385271
# 3  1441797  850544
# 4        7  105546

# %%
import numpy 
G =[]

for i in range(len(df)):
  graph = nx.Graph()
  for index, row in df[i].iterrows():
    if(numpy.issubdtype(type(row[0]), int) and numpy.issubdtype(type(row[1]), int)):
       graph.add_edge(row[0], row[1])
  G.append(graph)

# %%
from matplotlib import pyplot
degree_distribution = []
for i in range(len(G)):
  dd = [G[i].degree(n) for n in G[i].nodes()]
  degree_distribution.append(dd)
  pyplot.hist(dd)
  pyplot.xlim(0,100)
  pyplot.show()

# %%
for i in range(len(degree_distribution)):
  Sum = sum(degree_distribution[i])
  for idx, degree in enumerate(degree_distribution[i]):
    degree_distribution[i][idx] = degree/Sum

# %%
from math import log2
from matplotlib import pyplot

heatmap = []

def kl_divergence(p, q):
	kl_divergence = 0
	for i in range(min(len(p),len(q))):
		kl_divergence += p[i] * log2(p[i]/q[i])
	return kl_divergence

for i in range(0, len(degree_distribution)):
	p = degree_distribution[i]
	row = []
	for j in range(0,len(degree_distribution)):
		q = degree_distribution[j]
		row.append(kl_divergence(p,q))
	heatmap.append(row)

# %%
import seaborn as sn

hm = sn.heatmap(data = heatmap)
  
pyplot.show()

# %% [markdown]
# # Removing nodes with degree lesser than or equal to 5

# %%
degree_distribution = []
for i in range(len(G)):
  dd = [G[i].degree(n) for n in G[i].nodes()]
  dd[:] = [x for x in dd if x > 5]
  if(len(dd)):
    degree_distribution.append(dd)
    pyplot.hist(dd)
    pyplot.xlim(0,100)
    pyplot.show()

# %%
for i in range(len(degree_distribution)):
  Sum = sum(degree_distribution[i])
  for idx, degree in enumerate(degree_distribution[i]):
    degree_distribution[i][idx] = degree/Sum

# %%
heatmap2 = []

def kl_divergence(p, q):
	kl_divergence = 0
	for i in range(min(len(p),len(q))):
		kl_divergence += p[i] * log2(p[i]/q[i])
	return kl_divergence

for i in range(0, len(degree_distribution)):
  p = degree_distribution[i]
  row = []
  for j in range(0,len(degree_distribution)):
    q = degree_distribution[j]
    if j>=i :
      row.append(kl_divergence(p,q))
    else:
      row.append(heatmap2[j][i])
  heatmap2.append(row)

# %%
import seaborn as sn

hm = sn.heatmap(data = heatmap2)
  
pyplot.show()
